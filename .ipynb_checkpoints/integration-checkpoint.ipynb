# %%
import numpy as np
import matplotlib.pyplot as plt
from plotspec import plotspec
from readspec import readspec
from dirspec import dirspec
from readID import readID
import sys

sys.path.append('./private')
from check_data import check_data

# %% [markdown]
# # FUNCTION TEST BED
# Write new functions here before making importable

# %%
# Now its own function
def readspec_test(filename, funit='hz', dunit='cart'):
    """
    Read a DIWASP spec file
    
    by Andrew
    """
    
    with open(filename) as f:

        datain = f.readlines()

    datain = [float(x.split()[0]) for x in datain]
    datain = np.array(datain)
    
    SM = {}
    SM['xaxisdir'] = datain[0]
    
    nfreq=int(datain[1])
    ndirs=int(datain[2])
    
    SM['freqs'] = datain[np.arange(3, nfreq+3)]
    SM['funit'] = funit

    SM['dirs'] = datain[np.arange(nfreq+3, nfreq+3+ndirs)]
    SM['dunit'] = dunit

    headercheck=datain[nfreq+ndirs+3];
    if headercheck!=999:
       raise(Exception('corrupt file header'))
    
    mat=datain[np.arange(nfreq+ndirs+4, nfreq+ndirs+4+(nfreq*ndirs))];
    S = np.reshape(mat, [nfreq, ndirs])
    SM['S'] = S
    
    return SM
# Now its own function
def readID_test(filename):
    """
    Read ID file
    
    %  Format
        % 
        % n
        % m (number of data types)
        % depth
        % fs
        % xyz
        % next 3 lines are the xyz row by row
        % /xyz
        % layout
        % next 3 lines are the layout row by row
        % /layout
        % type1
        % next n lines are data type 1
        % type2
        % next n lines are data type 2
        % type3
        % next n lines are data type 3
        % etc

    by Andrew
    """
    
    with open(filename) as f:

        n = int(float(f.readline().split()[0]))
        m = int(float(f.readline().split()[0]))
        depth = int(float(f.readline().split()[0]))
        fs = int(float(f.readline().split()[0]))
        
#         f.readline()
#         l1 = [float(x) for x in f.readline().split()]
#         l2 = [float(x) for x in f.readline().split()]
#         l3 = [float(x) for x in f.readline().split()]
#         xyz = np.array([l1, l2, l3])        
#         f.readline()
        
        print(f.readline())
        l1 = [float(x) for x in f.readline().split()]
        l2 = [float(x) for x in f.readline().split()]
        l3 = [float(x) for x in f.readline().split()]
        layout = np.array([l1, l2, l3])        
        print(f.readline())
        
        datatypes = []
        data = []
        for i in np.arange(0, m):
            dt = f.readline()
            print(dt)
            datatypes.append(dt)
            data.append([float(f.readline().split()[0]) for i in np.arange(0, n)])

        
    ID = {}
    ID['n'] = n
    ID['m'] = m
    
    ID['depth'] = depth
    ID['fs'] = fs

#     ID['xyz'] = xyz
    ID['layout'] = layout

    ID['datatypes'] = datatypes
    ID['data'] = np.array(data).T

    return ID

# %% [markdown]
# # Import Spectra From Matlab
# Can't make spectra in pyDIWASP as makespec has not been translated yet. Just read some Matlab spectra. I'll also read the ID data made by Matlab's makespec. I'll write my own readID function and in keeping with the spirit of writespec te file will be one long list of numbers.
#
# SM and ID were in Matlab using makespec.
#
# SMout was made in dirspec using SM and ID.
#
# At the moment I'm not writing an EP writer so I'll just match that manually.

# %%
SM = readspec(r'C:\Users\20270917\Dropbox\WorkRelated\O2\diwasp_test\SM.spec')
SMout = readspec(r'C:\Users\20270917\Dropbox\WorkRelated\O2\diwasp_test\SMout.spec')
ID = readID(r'C:\Users\20270917\Dropbox\WorkRelated\O2\diwasp_test\ID.id')

EP = {}
EP['method'] = 'IMLM' # This is the only method supported by Python
EP['nfft'] = 2048*4
EP['dres'] = len(SM['dirs'])
EP['iter'] = 1000
EP['smooth']= 'OFF'
EP
# Out:
# in
# open
# read
# comprehended
# in
# open
# read
# comprehended
# layout:
#
# /layout:
#
# ['elev\n']
# ['elev\n', 'velx\n']
# ['elev\n', 'velx\n', 'vely\n']
# {'method': 'IMLM', 'nfft': 8192, 'dres': 60, 'iter': 1000, 'smooth': 'OFF'}

# %%
plt.figure()
plt.pcolor(SM['dirs'], SM['freqs'], SM['S'], vmax=0.02)
plt.title('DIWASP Input Spectrum')
plt.ylabel('Freq (Hz)')
plt.xlabel('Dir (deg)')

cb = plt.colorbar()
cb.set_label('m$^2$/(Hz.deg)')
plt.show()

plotspec(SM, 3)

plt.figure()
plt.pcolor(SMout['dirs'], SMout['freqs'], SMout['S'], vmax=0.02)
plt.title('DIWASP Output Spectrum')
plt.ylabel('Freq (Hz)')
plt.xlabel('Dir (deg)')

cb = plt.colorbar()
cb.set_label('m$^2$/(Hz.deg)')

plotspec(SMout, 3)
plt.show()

# %% [markdown]
# # TEST pyDIWASP
# Now import the data used to make the above spectra and test pyDIWASP

# %%
plt.plot(ID['data'][:, 0])
plt.show()

plt.plot(ID['data'][:, 1:3])
plt.show()
ID['data']
# Out:
# array([[-0.322719,  0.080574, -0.081318],
#        [-0.386619,  0.214456, -0.17034 ],
#        [-0.39526 ,  0.017481, -0.072341],
#        ...,
#        [ 0.052726,  0.065595,  0.018437],
#        [ 0.010321, -0.015898, -0.089339],
#        [-0.144618,  0.175048, -0.028774]])

# %% [markdown]
# # TRANSFER FUNCTIONS
# Got to track these transfer functions. I think I'm interpreting something incorrectly.

# %%
check_data(ID, 1)
check_data(SM, 2)
check_data(EP, 3)

SM_test = SM.copy()
SM_test.pop('S', None)

SMpy, EPpy = dirspec(ID, SM_test, EP)
# Out:
# Spectral matrix structure error: field [S] not specified correctly
#
# calculating.....
#
# cross power spectra
# wavenumbers
# transfer parameters
#
# directional spectra using IMLM method
# calculating for frequency 1 of 170
# calculating for frequency 2 of 170
# C:\Users\20270917\Dropbox\University\PhD\03_CODE\Source_code\pyDIWASP\dirspec.py:105: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#
# calculating for frequency 108 of 170
# calculating for frequency 109 of 170
# calculating for frequency 110 of 170
# calculating for frequency 111 of 170
# calculating for frequency 112 of 170
# calculating for frequency 113 of 170
# calculating for frequency 114 of 170
# calculating for frequency 115 of 170
# calculating for frequency 116 of 170
# calculating for frequency 117 of 170
# calculating for frequency 118 of 170
# calculating for frequency 119 of 170
# calculating for frequency 120 of 170
# calculating for frequency 121 of 170
# calculating for frequency 122 of 170
# calculating for frequency 123 of 170
# calculating for frequency 124 of 170
# calculating for frequency 125 of 170
# calculating for frequency 126 of 170
# calculating for frequency 127 of 170
# calculating for frequency 128 of 170
# calculating for frequency 129 of 170
# calculating for frequency 130 of 170
# calculating for frequency 131 of 170
# calculating for frequency 132 of 170
# calculating for frequency 133 of 170
# calculating for frequency 134 of 170
# calculating for frequency 135 of 170
# calculating for frequency 136 of 170
# calculating for frequency 137 of 170
# calculating for frequency 138 of 170
# calculating for frequency 139 of 170
# calculating for frequency 140 of 170
# calculating for frequency 141 of 170
# calculating for frequency 142 of 170
# calculating for frequency 143 of 170
# calculating for frequency 144 of 170
# calculating for frequency 145 of 170
# calculating for frequency 146 of 170
# calculating for frequency 147 of 170
# calculating for frequency 148 of 170
# calculating for frequency 149 of 170
# calculating for frequency 150 of 170
# calculating for frequency 151 of 170
# calculating for frequency 152 of 170
# calculating for frequency 153 of 170
# calculating for frequency 154 of 170
# calculating for frequency 155 of 170
# calculating for frequency 156 of 170
# calculating for frequency 157 of 170
# calculating for frequency 158 of 170
# calculating for frequency 159 of 170
# calculating for frequency 160 of 170
# calculating for frequency 161 of 170
# calculating for frequency 162 of 170
# calculating for frequency 163 of 170
# calculating for frequency 164 of 170
# calculating for frequency 165 of 170
# calculating for frequency 166 of 170
# calculating for frequency 167 of 170
# calculating for frequency 168 of 170
# calculating for frequency 169 of 170
# calculating for frequency 170 of 170
#
# interpolating onto specified matrix...
#
# Infospec::
# Significant wave height: 3.4089095297078744
# Peak period: 4.760589932304411
# Direction of peak period: 126.0 axis angle / 144.0 compass bearing
# Dominant direction: 126.0 axis angle / 144.0 compass bearing
# finished...plotting spectrum
# C:\Users\20270917\Dropbox\University\PhD\03_CODE\Source_code\pyDIWASP\interpspec.py:45: UserWarning: User defined grid may be too coarse; try increasing resolution of SM['freqs'] or SM['dirs']
#   warn('User defined grid may be too coarse; try increasing' +

# %%
plt.figure()
plt.pcolor(SMpy['dirs'], SMpy['freqs'], np.real(SMpy['S']), vmax=0.02)
plt.title('pyDIWASP Output Spectrum')
plt.ylabel('Freq (Hz)')
plt.xlabel('Dir (deg)')

cb = plt.colorbar()
cb.set_label('m$^2$/(Hz.deg)')

plotspec(SMpy, 3)
plt.show()

# %% [markdown]
# # Emilio
# Go to understand how each step fits in with the depth transfer functions and how they are transforming the data. Then we test against our spectral code and we're done.
